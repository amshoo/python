# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read dataset 
fh=open("DataSet/email.txt", 'rb')
H = nx.read_weighted_edgelist(fh,nodetype=None, encoding='utf-8')
fh.close()

# %%
H.number_of_nodes(),H.number_of_edges()
# Out:
# (1133, 5452)

# %%
#return the original node_name and the new_assign_name. 
def nodes():
    n_name =[]
    i = 1
    for j in H.nodes: 
        E = (j, i)
        i+=1
        n_name.append(E)            
    return  n_name
n_name = pd.DataFrame(nodes(),columns = ('nodes_name','new_name'))
#n_name.to_csv('result/celegansneural/celegansneural_dict.csv')

# %%
n_name
# Out:
#     nodes_name  new_name
# 0            1         1
# 1            2         2
# 2            4         3
# 3            8         4
# 4            3         5
# 5            5         6
# 6           26         7
# 7           47         8
# 8            6         9
# 9            7        10
# 10          13        11
# 11          16        12
# 12          23        13
# 13          24        14
# 14          27        15
# 15          28        16
# 16          30        17
# 17          34        18
# 18          35        19
# 19          36        20
# 20          37        21
# 21          38        22
# 22          65        23
# 23          67        24
# 24         112        25
# 25         118        26
# 26         144        27
# 27         201        28
# 28         248        29
# 29         313        30
# ..         ...       ...
# 302        289       303
# 303        257       304
# 304        264       305
# 305        268       306
# 306        269       307
# 307        270       308
# 308        277       309
# 309        278       310
# 310        279       311
# 311        280       312
# 312        282       313
# 313        290       314
# 314        291       315
# 315        294       316
# 316        303       317
# 317        304       318
# 318        308       319
# 319        309       320
# 320        312       321
# 321        314       322
# 322        315       323
# 323        317       324
# 324        319       325
# 325        326       326
# 326        329       327
# 327        323       328
# 328        327       329
# 329        328       330
# 330        330       331
# 331        332       332
#
# [332 rows x 2 columns]

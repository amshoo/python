# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
propose = pd.read_csv('result/power/ranking_table_power1.csv')
all_in = pd.concat([propose], axis=1, sort=False)

Top_Five_all_in = pd.DataFrame(all_in.loc[0:4])
ranking_table_all_in = pd.concat([Top_Five_all_in['NDR'],Top_Five_all_in['TR'], Top_Five_all_in['BC'], Top_Five_all_in['CNC'],
                                  Top_Five_all_in['DC'], Top_Five_all_in['EC'],Top_Five_all_in['PR'],
                                  Top_Five_all_in['TC'], 
                                  Top_Five_all_in['PI'], Top_Five_all_in['CC'],Top_Five_all_in['TPN']], 
                                 axis=1, sort=False)
#float_col = ranking_table_all_in.select_dtypes(include = ['float64']) # This will select float columns only
# list(float_col.columns.values)
#for col in float_col.columns.values:
#    ranking_table_all_in[col] = ranking_table_all_in[col].astype('int64')
#ranking_table_all_in.to_csv('result/usair/ranking_table_all_in_usair_network.csv')
ranking_table_all_in
# Out:
#       NDR    TR    BC   CNC    DC    EC    PR      TC      PI      CC     TPN
# 0  4345.0  4384  4164  1308  2553  4381   831  4345.0  4384.0  2553.0  4384.0
# 1  4384.0  4345  2543  2594  4458  4345  4458  4384.0  4345.0  2617.0  4345.0
# 2  4352.0  4352  1243  2605   831  4336  3468  4352.0  4352.0  1091.0  4352.0
# 3  4381.0  4381  4219  1131  3468  4332  2553  4381.0  4381.0  3312.0  2553.0
# 4  4373.0  4373  2528  2606  4345  4352  1224  4373.0  4395.0  2586.0  1091.0

# %%
# calculate the kendall's correlation between variables
kd=ranking_table_all_in.corr(method ='kendall')
#kd.to_csv('result/usair/correlation/kdcorr_matrix_usair.csv')
kd
# Out:
#      NDR   TR   BC  CNC   DC   EC   PR   TC   PI   CC  TPN
# NDR  1.0 -0.4  0.2  0.0  0.6 -0.4  0.6  1.0 -0.4  0.6 -0.4
# TR  -0.4  1.0  0.4 -0.2 -0.4  0.2 -0.8 -0.4  0.6  0.0  0.2
# BC   0.2  0.4  1.0 -0.8  0.2  0.0 -0.2  0.2  0.0  0.6  0.0
# CNC  0.0 -0.2 -0.8  1.0  0.0  0.2  0.0  0.0  0.2 -0.4 -0.2
# DC   0.6 -0.4  0.2  0.0  1.0  0.0  0.2  0.6  0.0  0.6 -0.4
# EC  -0.4  0.2  0.0  0.2  0.0  1.0 -0.4 -0.4  0.2 -0.4  0.2
# PR   0.6 -0.8 -0.2  0.0  0.2 -0.4  1.0  0.6 -0.8  0.2  0.0
# TC   1.0 -0.4  0.2  0.0  0.6 -0.4  0.6  1.0 -0.4  0.6 -0.4
# PI  -0.4  0.6  0.0  0.2  0.0  0.2 -0.8 -0.4  1.0  0.0 -0.2
# CC   0.6  0.0  0.6 -0.4  0.6 -0.4  0.2  0.6  0.0  1.0 -0.4
# TPN -0.4  0.2  0.0 -0.2 -0.4  0.2  0.0 -0.4 -0.2 -0.4  1.0

# %%
# calculate the pearson's correlation between variables 
ps=ranking_table_all_in.corr(method ='pearson')
#ps.to_csv('result/usair/correlation/pscorr_matrix_usair.csv')
ps
# Out:
#           NDR        TR        BC       CNC        DC        EC        PR  \
# NDR  1.000000 -0.236585  0.081662  0.144830  0.778439 -0.585434  0.456905
# TR  -0.236585  1.000000  0.797492 -0.796442  0.071222  0.445870 -0.873764
# BC   0.081662  0.797492  1.000000 -0.907126  0.344650  0.407560 -0.506950
# CNC  0.144830 -0.796442 -0.907126  1.000000  0.052637 -0.268637  0.452265
# DC   0.778439  0.071222  0.344650  0.052637  1.000000  0.034479 -0.021440
# EC  -0.585434  0.445870  0.407560 -0.268637  0.034479  1.000000 -0.667703
# PR   0.456905 -0.873764 -0.506950  0.452265 -0.021440 -0.667703  1.000000
# TC   1.000000 -0.236585  0.081662  0.144830  0.778439 -0.585434  0.456905
# PI  -0.104527  0.895379  0.561986 -0.457977  0.263165  0.397119 -0.921200
# CC   0.593293  0.549535  0.833185 -0.589435  0.768378  0.096101 -0.261203
# TPN -0.438026 -0.423407 -0.122943 -0.042915 -0.516843  0.198497  0.448481
#
#            TC        PI        CC       TPN
# NDR  1.000000 -0.104527  0.593293 -0.438026
# TR  -0.236585  0.895379  0.549535 -0.423407
# BC   0.081662  0.561986  0.833185 -0.122943
# CNC  0.144830 -0.457977 -0.589435 -0.042915
# DC   0.778439  0.263165  0.768378 -0.516843
# EC  -0.585434  0.397119  0.096101  0.198497
# PR   0.456905 -0.921200 -0.261203  0.448481
# TC   1.000000 -0.104527  0.593293 -0.438026
# PI  -0.104527  1.000000  0.492445 -0.727744
# CC   0.593293  0.492445  1.000000 -0.431852
# TPN -0.438026 -0.727744 -0.431852  1.000000

# %%
#import scipy.stats
#scipy.stats.spearmanr(data1,data2)

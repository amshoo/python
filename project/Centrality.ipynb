# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def graph():    
    import graph
    Graph = graph.H
    return Graph
G = graph()
#G= nx.karate_club_graph()

# %% [markdown]
# ## 1-Degree Centrality
# #Ranking degree

# %%
def Degree_Ranking( val ):
      return val [1]
degree = list(nx.degree_centrality(G).items())
degree.sort(key=lambda elem: elem[1], reverse=True)
degree_table = pd.DataFrame(degree, columns = ('DC','DC_i'))

# %% [markdown]
# ## 2-Betweeness Centrality
# #Ranking degree

# %%
def Betweeness_Ranking( val ):
      return val [1]
Betweeness = list(nx.betweenness_centrality(G).items())
Betweeness.sort(key=lambda elem: elem[1], reverse=True)
Betweeness_table = pd.DataFrame(Betweeness, columns = ('BC','BC_i'))

# %% [markdown]
# ## 3-closeness Centrality
# #Ranking closeness

# %%
def closeness_Ranking( val ):
      return val [1]
closeness = list(nx.closeness_centrality(G).items())
closeness.sort(key=lambda elem: elem[1], reverse=True)
closeness_table = pd.DataFrame(closeness, columns = ('CNC','CNC_i'))

# %% [markdown]
# ## 4-eigenvector Centrality
# #Ranking eigenvector

# %%
def eigenvector_Ranking( val ):
      return val [1]
eigenvector = list(nx.eigenvector_centrality(G).items())
eigenvector.sort(key=lambda elem: elem[1], reverse=True)
eigenvector_table = pd.DataFrame(eigenvector, columns = ('EC','EC_i'))

# %% [markdown]
# ## 5-Triangles Centrality
# #Ranking triangles

# %%
def triangles_Ranking( val ):
      return val [1]
triangles = list(nx.triangles(G, nodes=None).items())
triangles.sort(key=lambda elem: elem[1], reverse=True)
triangles_table = pd.DataFrame(triangles, columns = ('TR','TR_i'))

# %% [markdown]
# ## 6- Pagerank Ranking
# #Ranking pagerank

# %%
def pagerank_Ranking( val ):
      return val [1]
pagerank = list(nx.pagerank(G, alpha=0.3).items())
pagerank.sort(key=lambda elem: elem[1], reverse=True)
pagerank_table = pd.DataFrame(pagerank, columns = ('PR','PR_i'))

# %%
power_table = pd.concat([triangles_table,eigenvector_table, 
                         closeness_table,Betweeness_table, 
                         degree_table,pagerank_table], 
                                 axis=1, sort=False)
power_table.index = power_table.index + 1
Top_ = pd.DataFrame(power_table.loc[0:10])

# %%
#power_table.to_csv('result/cent_kc.csv')#save top three ranking of the Classical Centrality

# %%
power_table
# Out:
#     TR  TR_i  EC      EC_i  CNC     CNC_i  BC      BC_i  DC      DC_i  PR  \
# 1    0    18  33  0.373371    0  0.568966   0  0.437635  33  0.515152  33
# 2   33    15   0  0.355483    2  0.559322  33  0.304075   0  0.484848   0
# 3   32    13   2  0.317189   33  0.550000  32  0.145247  32  0.363636  32
# 4    1    12  32  0.308651   31  0.540984   2  0.143657   2  0.303030   1
# 5    2    11   1  0.265954    8  0.515625  31  0.138276   1  0.272727   2
# 6    3    10   8  0.227405   13  0.515625   8  0.055927   3  0.181818  31
# 7    7     6  13  0.226470   32  0.515625   1  0.053937  31  0.181818   3
# 8   13     6   3  0.211174   19  0.500000  13  0.045863   8  0.151515   5
# 9    8     5  31  0.191036    1  0.485294  19  0.032475  13  0.151515   6
# 10  23     4  30  0.174760    3  0.464789   5  0.029987  23  0.151515  23
# 11  29     4   7  0.170955   27  0.458333   6  0.029987   5  0.121212  29
# 12   5     3  23  0.150123   30  0.458333  27  0.022333   6  0.121212  27
# 13   6     3  19  0.147911   28  0.452055  23  0.017614   7  0.121212   8
# 14  30     3  29  0.134965    7  0.440000  30  0.014412  27  0.121212  24
# 15  31     3  27  0.133479    9  0.434211   3  0.011909  29  0.121212  13
# 16   4     2  28  0.131079   23  0.392857  25  0.003840  30  0.121212   4
# 17  10     2   9  0.102675    5  0.383721  29  0.002922   4  0.090909  10
# 18  12     1  14  0.101406    6  0.383721  24  0.002210  10  0.090909  25
# 19  14     1  15  0.101406   29  0.383721  28  0.001795  19  0.090909  30
# 20  15     1  18  0.101406    4  0.379310   9  0.000848  24  0.090909   7
# 21  16     1  20  0.101406   10  0.379310   4  0.000631  25  0.090909  16
# 22  17     1  22  0.101406   17  0.375000  10  0.000631  28  0.090909  28
# 23  18     1  17  0.092397   21  0.375000   7  0.000000   9  0.060606  19
# 24  19     1  21  0.092397   24  0.375000  11  0.000000  12  0.060606  26
# 25  20     1  12  0.084252   25  0.375000  12  0.000000  14  0.060606  12
# 26  21     1   5  0.079481   12  0.370787  14  0.000000  15  0.060606  17
# 27  22     1   6  0.079481   14  0.370787  15  0.000000  16  0.060606  21
# 28  24     1   4  0.075966   15  0.370787  16  0.000000  17  0.060606  14
# 29  25     1  10  0.075966   18  0.370787  17  0.000000  18  0.060606  15
# 30  26     1  26  0.075582   20  0.370787  18  0.000000  20  0.060606  18
# 31  27     1  25  0.059208   22  0.370787  20  0.000000  21  0.060606  20
# 32  28     1  24  0.057054   11  0.366667  21  0.000000  22  0.060606  22
# 33   9     0  11  0.052854   26  0.362637  22  0.000000  26  0.060606   9
# 34  11     0  16  0.023635   16  0.284483  26  0.000000  11  0.030303  11
#
#         PR_i
# 1   0.063634
# 2   0.060638
# 3   0.049160
# 4   0.039268
# 5   0.038933
# 6   0.031880
# 7   0.031241
# 8   0.030450
# 9   0.030450
# 10  0.029780
# 11  0.028302
# 12  0.027356
# 13  0.027186
# 14  0.026900
# 15  0.026887
# 16  0.026677
# 17  0.026677
# 18  0.026659
# 19  0.025880
# 20  0.025764
# 21  0.025156
# 22  0.024473
# 23  0.024157
# 24  0.023834
# 25  0.023287
# 26  0.023034
# 27  0.023034
# 28  0.022940
# 29  0.022940
# 30  0.022940
# 31  0.022940
# 32  0.022940
# 33  0.022879
# 34  0.021725

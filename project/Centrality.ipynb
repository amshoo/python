# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def graph():    
    import graph
    Graph = graph.H
    return Graph
G = graph()
#G= nx.karate_club_graph()

# %% [markdown]
# ## 1-Degree Centrality
# #Ranking degree

# %%
def Degree_Ranking( val ):
      return val [1]
degree = list(nx.degree_centrality(G).items())
degree.sort(key=lambda elem: elem[1], reverse=True)
degree_table = pd.DataFrame(degree, columns = ('DC','DC_i'))

# %% [markdown]
# ## 2-Betweeness Centrality
# #Ranking degree

# %%
def Betweeness_Ranking( val ):
      return val [1]
Betweeness = list(nx.betweenness_centrality(G).items())
Betweeness.sort(key=lambda elem: elem[1], reverse=True)
Betweeness_table = pd.DataFrame(Betweeness, columns = ('BC','BC_i'))

# %% [markdown]
# ## 3-closeness Centrality
# #Ranking closeness

# %%
def closeness_Ranking( val ):
      return val [1]
closeness = list(nx.closeness_centrality(G).items())
closeness.sort(key=lambda elem: elem[1], reverse=True)
closeness_table = pd.DataFrame(closeness, columns = ('CNC','CNC_i'))

# %% [markdown]
# ## 4-eigenvector Centrality
# #Ranking eigenvector

# %%
def eigenvector_Ranking( val ):
      return val [1]
eigenvector = list(nx.eigenvector_centrality(G).items())
eigenvector.sort(key=lambda elem: elem[1], reverse=True)
eigenvector_table = pd.DataFrame(eigenvector, columns = ('EC','EC_i'))

# %% [markdown]
# ## 5-Triangles Centrality
# #Ranking triangles

# %%
def triangles_Ranking( val ):
      return val [1]
triangles = list(nx.triangles(G, nodes=None).items())
triangles.sort(key=lambda elem: elem[1], reverse=True)
triangles_table = pd.DataFrame(triangles, columns = ('TR','TR_i'))

# %% [markdown]
# ## 6- Pagerank Ranking
# #Ranking pagerank

# %%
def pagerank_Ranking( val ):
      return val [1]
pagerank = list(nx.pagerank(G, alpha=0.3).items())
pagerank.sort(key=lambda elem: elem[1], reverse=True)
pagerank_table = pd.DataFrame(pagerank, columns = ('PR','PR_i'))

# %%
power_table = pd.concat([triangles_table,eigenvector_table, 
                         closeness_table,Betweeness_table, 
                         degree_table,pagerank_table], 
                                 axis=1, sort=False)
power_table.index = power_table.index + 1
Top_ = pd.DataFrame(power_table.loc[0:10])

# %%
#power_table.to_csv('result/cent_ns.csv')#save top three ranking of the Classical Centrality

# %%
power_table
# Out:
#         TR  TR_i    EC          EC_i   CNC     CNC_i    BC      BC_i    DC  \
# 1     1429   173  1429  2.249711e-01    78  0.066440    78  0.026572    33
# 2     1430   173  1430  2.249711e-01   281  0.064470   150  0.023090    34
# 3     1431   173  1431  2.249711e-01   150  0.063965   516  0.019135    78
# 4      645   171   645  2.231994e-01   756  0.062936   281  0.018074    54
# 5     1432   171  1432  2.231994e-01   301  0.060299   216  0.017088   294
# 6     1433   171  1433  2.231994e-01   151  0.059711    34  0.016767  1429
# 7     1434   171  1434  2.231994e-01    34  0.059457   756  0.015498  1430
# 8     1435   171  1435  2.231994e-01   131  0.057568   301  0.014822  1431
# 9     1436   171  1436  2.231994e-01   759  0.057031   131  0.011699    62
# 10    1437   171  1437  2.231994e-01  1123  0.056932   203  0.011686   216
# 11    1438   171  1438  2.231994e-01   757  0.056899   151  0.010463   645
# 12    1439   171  1439  2.231994e-01   758  0.056899    33  0.010173  1432
# 13    1440   171  1440  2.231994e-01  1178  0.056472    46  0.009930  1433
# 14    1441   171  1441  2.231994e-01  1342  0.056472   219  0.008367  1434
# 15    1442   171  1442  2.231994e-01   203  0.056084    30  0.006119  1435
# 16    1443   171  1443  2.231994e-01    46  0.056019   307  0.005824  1436
# 17    1444   171  1444  2.231994e-01   516  0.055891    72  0.004839  1437
# 18    1445   171  1445  2.231994e-01    71  0.055448   654  0.004683  1438
# 19    1446   171  1446  2.231994e-01    33  0.055229    71  0.004474  1439
# 20    1447   171  1447  2.231994e-01    69  0.055167   327  0.004321  1440
# 21      33    75  1448  3.547729e-02    72  0.055012    53  0.003709  1441
# 22      34    64    33  6.702250e-05    30  0.054827   127  0.003133  1442
# 23      54    58    34  5.774200e-05   761  0.054827   184  0.003118  1443
# 24      62    54    54  5.605417e-05   762  0.054430   697  0.003118  1444
# 25     916    51    53  4.136853e-05   763  0.054430   596  0.003051  1445
# 26     913    48   132  3.833329e-05   517  0.054370   402  0.003040  1446
# 27    1201    44   133  3.530940e-05   225  0.054310    55  0.002865  1447
# 28     219    41   134  3.530940e-05   760  0.054310    51  0.002817   219
# 29     294    41   561  3.530940e-05   307  0.054069    69  0.002805   281
# 30      53    40   562  3.530940e-05   308  0.053743   194  0.002793    53
# ...    ...   ...   ...           ...   ...       ...   ...       ...   ...
# 1432  1480     0  1371  2.177998e-17  1371  0.000685  1556  0.000000  1455
# 1433  1479     0  1370  2.177998e-17  1370  0.000685  1557  0.000000  1480
# 1434  1487     0  1373  2.177998e-17  1373  0.000685  1558  0.000000  1479
# 1435  1486     0  1372  2.177998e-17  1372  0.000685  1560  0.000000  1487
# 1436  1492     0  1387  2.177998e-17  1387  0.000685  1561  0.000000  1486
# 1437  1494     0  1386  2.177998e-17  1386  0.000685  1562  0.000000  1492
# 1438  1496     0  1450  2.177998e-17  1450  0.000685  1563  0.000000  1494
# 1439  1495     0  1449  2.177998e-17  1449  0.000685  1564  0.000000  1496
# 1440  1497     0  1453  2.177998e-17  1453  0.000685  1565  0.000000  1495
# 1441  1498     0  1360  2.177998e-17  1360  0.000685  1566  0.000000  1497
# 1442  1523     0  1480  2.177998e-17  1480  0.000685  1567  0.000000  1498
# 1443  1522     0  1479  2.177998e-17  1479  0.000685  1569  0.000000  1523
# 1444  1526     0  1487  2.177998e-17  1487  0.000685  1568  0.000000  1522
# 1445  1525     0  1486  2.177998e-17  1486  0.000685  1570  0.000000  1526
# 1446  1531     0  1496  2.177998e-17  1496  0.000685  1571  0.000000  1525
# 1447  1530     0  1495  2.177998e-17  1495  0.000685  1572  0.000000  1531
# 1448  1532     0  1523  2.177998e-17  1523  0.000685  1573  0.000000  1530
# 1449  1536     0  1522  2.177998e-17  1522  0.000685  1574  0.000000  1532
# 1450  1544     0  1526  2.177998e-17  1526  0.000685  1576  0.000000  1536
# 1451  1543     0  1525  2.177998e-17  1525  0.000685  1575  0.000000  1544
# 1452  1549     0  1531  2.177998e-17  1531  0.000685  1577  0.000000  1543
# 1453  1569     0  1530  2.177998e-17  1530  0.000685  1578  0.000000  1549
# 1454  1568     0  1544  2.177998e-17  1544  0.000685  1579  0.000000  1569
# 1455  1581     0  1543  2.177998e-17  1543  0.000685  1581  0.000000  1568
# 1456  1580     0  1569  2.177998e-17  1569  0.000685  1580  0.000000  1581
# 1457  1584     0  1568  2.177998e-17  1568  0.000685  1584  0.000000  1580
# 1458  1583     0  1581  2.177998e-17  1581  0.000685  1583  0.000000  1584
# 1459  1586     0  1580  2.177998e-17  1580  0.000685  1586  0.000000  1583
# 1460  1585     0  1584  2.177998e-17  1584  0.000685  1587  0.000000  1586
# 1461  1587     0  1583  2.177998e-17  1583  0.000685  1588  0.000000  1587
#
#           DC_i    PR      PR_i
# 1     0.023288    78  0.002516
# 2     0.018493    33  0.002364
# 3     0.018493   281  0.001690
# 4     0.014384   216  0.001519
# 5     0.013699    34  0.001437
# 6     0.013699   294  0.001427
# 7     0.013699    46  0.001401
# 8     0.013699   516  0.001379
# 9     0.013014   327  0.001305
# 10    0.013014   219  0.001305
# 11    0.013014    96  0.001296
# 12    0.013014    62  0.001260
# 13    0.013014   654  0.001258
# 14    0.013014   150  0.001248
# 15    0.013014    69  0.001245
# 16    0.013014   244  0.001228
# 17    0.013014   151  0.001220
# 18    0.013014   631  0.001214
# 19    0.013014    54  0.001176
# 20    0.013014   482  0.001166
# 21    0.013014   415  0.001156
# 22    0.013014   121  0.001149
# 23    0.013014    71  0.001148
# 24    0.013014    53  0.001134
# 25    0.013014     9  0.001134
# 26    0.013014   517  0.001127
# 27    0.013014   194  0.001115
# 28    0.012329  1018  0.001114
# 29    0.011644   973  0.001102
# 30    0.010959   308  0.001096
# ...        ...   ...       ...
# 1432  0.000685  1451  0.000521
# 1433  0.000685  1086  0.000521
# 1434  0.000685  1089  0.000521
# 1435  0.000685  1549  0.000520
# 1436  0.000685  1460  0.000520
# 1437  0.000685    90  0.000520
# 1438  0.000685   934  0.000519
# 1439  0.000685  1461  0.000519
# 1440  0.000685   674  0.000519
# 1441  0.000685  1295  0.000518
# 1442  0.000685   653  0.000517
# 1443  0.000685   656  0.000517
# 1444  0.000685   894  0.000517
# 1445  0.000685  1452  0.000517
# 1446  0.000685  1008  0.000516
# 1447  0.000685    52  0.000516
# 1448  0.000685  1551  0.000515
# 1449  0.000685  1123  0.000514
# 1450  0.000685   310  0.000514
# 1451  0.000685  1221  0.000513
# 1452  0.000685   641  0.000512
# 1453  0.000685  1005  0.000512
# 1454  0.000685  1172  0.000512
# 1455  0.000685  1341  0.000510
# 1456  0.000685   745  0.000509
# 1457  0.000685  1529  0.000509
# 1458  0.000685   865  0.000508
# 1459  0.000685  1177  0.000508
# 1460  0.000685   839  0.000507
# 1461  0.000685   485  0.000503
#
# [1461 rows x 12 columns]
